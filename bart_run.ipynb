# %%
from main import *

# read the phones from the TIMIT dataset
train_set_phones, test_set_phones = get_phones()

# stretch the phones to the same length
stretch_phones(train_set_phones)
stretch_phones(test_set_phones)

# get the new mfcc
for phone in train_set_phones:
    phone.get_mfcc_seq()
for phone in test_set_phones:
    phone.get_mfcc_seq()

# get a random sample of 1000 phones from the test set
test_phones = random.sample(test_set_phones, 1000)

# test
test(train_set_phones, test_phones)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: n_fft=512 is too small for input signal of length=400
#   return f(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: n_fft=512 is too small for input signal of length=320
#   return f(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: n_fft=512 is too small for input signal of length=480
#   return f(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: n_fft=512 is too small for input signal of length=280
#   return f(*args, **kwargs)
# ...

# %%
import pandas as pd
from scipy.stats import bootstrap
import numpy as np

data = pd.read_csv('test_result.csv')
# if True phone == Predicted phone, add 1 to correct_num
data['correct'] = data['True phone'] == data['Predicted phone']
# get the accuracy

# get the confidence interval by bootstrapping
bootstrap_ci = bootstrap(
    data=(list(data['correct']),),
    statistic=lambda results, axis: sum(results) / len(results),
    confidence_level=0.95,
    method='percentile',
    random_state=114514,
)
print(bootstrap_ci)
